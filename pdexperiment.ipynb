# %% [markdown]
# # Pandas Library!

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv') #Reads a CSV file.

## Saves a dictionary as a data frame.
# pd.DataFrame({'a': ['b'], 'c': ['d']})

## Selecting data types.
# pd.DataFrame.select_dtypes()
# "pd.DataFrame() expects either a list of dicts, a dict of lists, or you must specify an index 
# if all values are scalars."

# df.columns (All the headers.)
# df.head(N) (First N rows.)
# df.tail(N) (Last N rows.)

## Read each row.
# df.iloc[10:50]

## Read each column.
# df[['Name', 'Type 1']]

## Read specific location.
# df.iloc[2, 1]  Written as: df[Row, Column]

## One condition and multiple conditions.
# df[df['Type 2'] == 'Psychic']
# df[(df['Type 1'] == 'Fire') & (df['HP'] > 100)]

## Sorting values alphabetically or by greatest or least.
# df.sort_values(['Name', 'Attack'], ascending = [0, 1]) 1 means ascending, 0 means descending.
# df.sort_values('Attack', ascending = False)

## Making a new column.
# df['Total'] = df['Attack'] + df['Defense']
# df['Total'] = df.iloc[:, 4:10].sum(axis = 1)
# df.head(50)

## Removing columns.
# df.drop(columns = ['Speed'])

## Saves data as a CSV, Excel, or text file respectively.
# df.to_csv('newpoke.csv', index = False) "index = False removes indexes on left side."
# df.to_excel('newpoke.xlsx', index = False)
# df.to_csv('newpoke.txt', index = False, sep = '\t') "Keyword sep separates values by tabs instead of commas."

# ndf = df[(df['Type 1'] == 'Fire') & (df['HP'] > 100)]
# ndf.reset_index(drop = True, inplace = True) "drop keyword removes original indexes, amd inplace conserves memory."

## Filtering out certain words or characters.
# df[~df['Name'].str.contains('Mega')] "~ character filters out words."

## Currently, I am not too familiar with the re or regular expressions module.
# import re
# df[df['Name'].str.contains('fire|grass', flags = re.I, regex = True)]

## Arranging data frames in a desired fashion with index, columns, & values keywords.
# df.pivot_table(index = 'Name', columns = ['Type 1', 'Type 2'])
# Out:
#                                #                                          \
# Type 1                       Bug
# Type 2                  Electric Fighting Fire Flying Ghost Grass Ground
# Name
# Abomasnow                    NaN      NaN  NaN    NaN   NaN   NaN    NaN
# AbomasnowMega Abomasnow      NaN      NaN  NaN    NaN   NaN   NaN    NaN
# AegislashBlade Forme         NaN      NaN  NaN    NaN   NaN   NaN    NaN
# AegislashShield Forme        NaN      NaN  NaN    NaN   NaN   NaN    NaN
# Aerodactyl                   NaN      NaN  NaN    NaN   NaN   NaN    NaN
# ...                          ...      ...  ...    ...   ...   ...    ...
# Zapdos                       NaN      NaN  NaN    NaN   NaN   NaN    NaN
# Zekrom                       NaN      NaN  NaN    NaN   NaN   NaN    NaN
# Zubat                        NaN      NaN  NaN    NaN   NaN   NaN    NaN
# Zweilous                     NaN      NaN  NaN    NaN   NaN   NaN    NaN
# Zygarde50% Forme             NaN      NaN  NaN    NaN   NaN   NaN    NaN
#
#                                            ...    Speed                     \
# Type 1                                     ...    Water
# Type 2                  Poison Rock Steel  ... Fighting Flying Ghost Grass
# Name                                       ...
# Abomasnow                  NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# AbomasnowMega Abomasnow    NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# AegislashBlade Forme       NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# AegislashShield Forme      NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# Aerodactyl                 NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# ...                        ...  ...   ...  ...      ...    ...   ...   ...
# Zapdos                     NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# Zekrom                     NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# Zubat                      NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# Zweilous                   NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
# Zygarde50% Forme           NaN  NaN   NaN  ...      NaN    NaN   NaN   NaN
#
#
# Type 1
# Type 2                  Ground Ice Poison Psychic Rock Steel
# Name
# Abomasnow                  NaN NaN    NaN     NaN  NaN   NaN
# AbomasnowMega Abomasnow    NaN NaN    NaN     NaN  NaN   NaN
# AegislashBlade Forme       NaN NaN    NaN     NaN  NaN   NaN
# AegislashShield Forme      NaN NaN    NaN     NaN  NaN   NaN
# Aerodactyl                 NaN NaN    NaN     NaN  NaN   NaN
# ...                        ...  ..    ...     ...  ...   ...
# Zapdos                     NaN NaN    NaN     NaN  NaN   NaN
# Zekrom                     NaN NaN    NaN     NaN  NaN   NaN
# Zubat                      NaN NaN    NaN     NaN  NaN   NaN
# Zweilous                   NaN NaN    NaN     NaN  NaN   NaN
# Zygarde50% Forme           NaN NaN    NaN     NaN  NaN   NaN
#
# [414 rows x 1224 columns]

# %%
df = {'mass (kg)': [9, 2, 8],
     'velocity (m/s)': [5, 7, 9]}

table = pd.DataFrame(df, columns = ['mass (kg)', 'velocity (m/s)'])

table['kinetic energy (J) '] = table['mass (kg)'] * (table['velocity (m/s)']) ** 2

table
